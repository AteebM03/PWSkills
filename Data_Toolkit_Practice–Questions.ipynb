# %%
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy Provide the code for each
# method and the final output after each method

import numpy as np
array1 = np.array([[1, 2, 3], [4, 5, 6]])
array1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array2 = np.zeros((2,3), dtype=int)
array2[0] = [1, 2, 3]
array2[1] = [4, 5, 6]
array2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array3 = np.full((2,3), 0)
array3[0] = [1, 2, 3]
array3[1] = [4, 5, 6]
array3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 2. Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and reshape that 1D array into a 2D array.
array_1D = np.linspace(1, 10, 100)
array_1D
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
array_2D = array_1D.reshape(10,10)
array_2D
# Out:
# array([[ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#          1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182],
#        [ 1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#          2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273],
#        [ 2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#          3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364],
#        [ 3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#          4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455],
#        [ 4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#          5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545],
#        [ 5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#          6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636],
#        [ 6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
# 3. Explain the following terms:
# The difference in np.array, np.asarray and np.asanyarray.
# The difference between Deep copy and shallow copy.

# 1. Differences between np.array, np.asarray, and np.asanyarray
# np.array:

# Purpose: Creates a new NumPy array.
# Behavior: Always returns a new array, regardless of the input type. This means that if the input is already an array, np.array will create a copy.

# np.asarray:

# Purpose: Converts the input to a NumPy array.
# Behavior: If the input is already an array, it will return the original array without copying it. This is more efficient when you want to avoid unnecessary copies.

# np.asanyarray:

# Purpose: Similar to np.asarray, but allows for subclasses of ndarray.
# Behavior: If the input is a subclass of ndarray (like np.matrix), it will return that subclass; otherwise, it behaves like np.asarray.


# 2. Differences between Deep Copy and Shallow Copy
# Shallow Copy:

# Definition: Creates a new object, but inserts references into it to the objects found in the original.
# Behavior: Changes to mutable objects within the shallow copy will reflect in the original object because both share references to the same inner objects.

# Deep Copy:

# Definition: Creates a new object and recursively adds copies of nested objects found in the original.
# Behavior: Changes to mutable objects within the deep copy do not affect the original object, as all objects are completely independent.

# %%
# 4. Generate a 3x3 array with random floating-point numbers between 5 and 20 then round each number in the array to 2 decimal places.

array3x3 = np.random.uniform(5, 20, (3, 3))
array3x3
# Out:
# array([[10.20542759, 12.57720527, 15.51692375],
#        [15.90677861, 17.80629685,  6.6282933 ],
#        [ 6.84435008, 16.62811544,  6.95492578]])

# %%
array3x3_2dp = np.round(array3x3, 2)
array3x3_2dp
# Out:
# array([[10.21, 12.58, 15.52],
#        [15.91, 17.81,  6.63],
#        [ 6.84, 16.63,  6.95]])

# %%
# 5. Create a NumPy array with random integers between 1 and 10 of shape (5, 6) After creating the array perform the following operations:

#  a)Extract all even integers from array.

#  b)Extract all odd integers from array.

array = np.random.randint(1, 11, size=(5, 6))
array
# Out:
# array([[ 8, 10, 10,  3,  5, 10],
#        [ 5,  1, 10,  8,  1,  2],
#        [ 2,  6,  2,  9,  6,  7],
#        [ 4,  7,  7,  5,  4,  9],
#        [10,  6,  5,  7,  8,  8]])

# %%
even = array[array % 2 == 0]
even
# Out:
# array([ 8, 10, 10, 10, 10,  8,  2,  2,  6,  2,  6,  4,  4, 10,  6,  8,  8])

# %%
odd = array[array % 2 != 0]
odd
# Out:
# array([3, 5, 5, 1, 1, 9, 7, 7, 7, 5, 9, 5, 7])

# %%
#  6. Create a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the following operations:

#  a) Find the indices of the maximum values along each depth level (third axis).

#  b) Perform element wise multiplication of between both arrays.

array_3D = np.random.randint(1, 11, size=(3, 3, 3))
array_3D
# Out:
# array([[[ 5,  6,  1],
#         [ 6,  2,  4],
#         [10, 10,  4]],
#
#        [[ 2,  4,  1],
#         [ 9, 10, 10],
#         [ 9,  1,  2]],
#
#        [[ 5,  7,  1],
#         [ 9,  5,  9],
#         [ 9,  7,  5]]])

# %%
indices_max = np.argmax(array_3D, axis=2)
indices_max
# Out:
# array([[1, 0, 0],
#        [1, 1, 0],
#        [1, 0, 0]])

# %%
mult_array = array_3D * indices_max
mult_array
# Out:
# array([[[ 5,  0,  0],
#         [ 6,  2,  0],
#         [10,  0,  0]],
#
#        [[ 2,  0,  0],
#         [ 9, 10,  0],
#         [ 9,  0,  0]],
#
#        [[ 5,  0,  0],
#         [ 9,  5,  0],
#         [ 9,  0,  0]]])

# %%
# 7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type.
# Also display the table attributes and data types of each column

import pandas as pd

file_url = 'https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'
df = pd.read_csv(file_url)
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name  Gender  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    27-01-2014
# 1  fergusonkatherine@example.net                 NaN    26-07-1931
# 2            fhoward@example.org       (599)782-0605    25-11-2013
# 3          zjohnston@example.com                 NaN    17-11-2012
# 4               elin@example.net  (390)417-1635x3010    15-04-1923
#
#                   Job Title  Salary
# 0         Probation officer   90000
# 1                    Dancer   80000
# 2                      Copy   50000
# 3  Counselling psychologist   65000
# 4       Biomedical engineer  100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          979 non-null    object
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
#  9   Salary         1000 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 78.2+ KB

# %%
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Gender           object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# Salary            int64
# dtype: object

# %%
df['Phone'] = df['Phone'].replace(r'[^\d]', '', regex=True).astype(float)
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email         Phone Date of birth  \
# 0              pwarner@example.org  8.571398e+09    27-01-2014
# 1    fergusonkatherine@example.net           NaN    26-07-1931
# 2              fhoward@example.org  5.997821e+09    25-11-2013
# ...

# %%
df.dtypes
# Out:
# Index              int64
# User Id           object
# First Name        object
# Last Name         object
# Gender            object
# Email             object
# Phone            float64
# Date of birth     object
# Job Title         object
# Salary             int64
# dtype: object

# %%
# 8 .Perform the following tasks using people dataset:

#  a) Read the 'data.csv' file using pandas, skipping the first 50 rows.

#  b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.

#  c) Display the first 10 rows of the filtered dataset.

#  d) Extract the ‘Salary’' column as a Series and display its last 5 values.

df = pd.read_csv('https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk', skiprows= [1, 51],
    usecols=['Last Name', 'Gender', 'Email', 'Phone', 'Salary'])
df
# Out:
#     Last Name  Gender                          Email                  Phone  \
# 0      Rivers  Female  fergusonkatherine@example.net                    NaN
# 1      Lowery  Female            fhoward@example.org          (599)782-0605
# 2      Hooper    Male          zjohnston@example.com                    NaN
# 3        Rice  Female               elin@example.net     (390)417-1635x3010
# 4    Caldwell    Male          kaitlin13@example.net             8537800927
# ..        ...     ...                            ...                    ...
# 993    Bryant  Female         lyonsdaisy@example.net           021.775.2933
# 994     Barry  Female        dariusbryan@example.com   001-149-710-7799x721
# 995  Mckinney  Female         georgechan@example.org  +1-750-774-4128x33265
# 996    Phelps    Male            wanda04@example.net          (915)292-2254
# 997      Tran  Female        deannablack@example.org     079.752.5424x67259
#
#      Salary
# 0     80000
# 1     50000
# 2     65000
# ...

# %%
df.head(10)
# Out:
#   Last Name  Gender                          Email               Phone  Salary
# 0    Rivers  Female  fergusonkatherine@example.net                 NaN   80000
# 1    Lowery  Female            fhoward@example.org       (599)782-0605   50000
# 2    Hooper    Male          zjohnston@example.com                 NaN   65000
# 3      Rice  Female               elin@example.net  (390)417-1635x3010  100000
# 4  Caldwell    Male          kaitlin13@example.net          8537800927   50000
# 5   Hoffman    Male         jeffharvey@example.com   093.655.7480x7895   60000
# 6  Andersen    Male           alicia33@example.org          4709522945   65000
# 7      Mays    Male             jake50@example.com        013.820.4758   50000
# 8  Mitchell    Male      lanechristina@example.net  (560)903-5068x4985   50000
# 9     Ayala    Male             ncantu@example.com          8629884096   60000

# %%
df['Salary'].tail()
# Out:
# 993     90000
# 994     50000
# 995     60000
# 996    100000
# 997     90000
# Name: Salary, dtype: int64

# %%
# 9. Filter and select rows from the People_Dataset, where the "Last Name" column contains the name 'Duke', 'Gender' column contains the word Female
# and ‘Salary’ should Pe less than 85000.

df = pd.read_csv('https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk')
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
filter =df[(df['Last Name'] == 'Duke') &
    (df['Gender'] == 'Female') &
    (df['Salary'] < 85000)]
filter
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
#  10. Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6.

arry =  np.random.randint(1, 7, size=35)
arry
# Out:
# array([6, 4, 4, 2, 3, 1, 3, 3, 3, 5, 6, 6, 5, 6, 3, 3, 3, 2, 2, 4, 2, 2,
#        3, 1, 5, 5, 2, 3, 1, 3, 4, 5, 2, 1, 2])

# %%
df = pd.DataFrame(arry.reshape(7,5), columns=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#    a  b  c  d  e
# 0  6  4  4  2  3
# 1  1  3  3  3  5
# 2  6  6  5  6  3
# 3  3  3  2  2  4
# 4  2  2  3  1  5
# 5  5  2  3  1  3
# 6  4  5  2  1  2

# %%
# Create two different Series, each of length 50, with the following criteria:

# a) The first Series should contain random numbers ranging from 10 to 50.

# b) The second Series should contain random numbers ranging from 100 to 1000.

# c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'col1', 'col2',etc.

series_1 = pd.Series(np.random.randint(10, 51, size=50))
series_1
# Out:
# 0     24
# 1     12
# 2     47
# 3     27
# 4     48
# 5     16
# 6     47
# 7     35
# 8     13
# 9     22
# 10    36
# 11    16
# 12    37
# 13    43
# 14    14
# 15    33
# 16    23
# 17    10
# 18    35
# 19    12
# 20    15
# 21    23
# 22    23
# 23    48
# 24    31
# 25    12
# 26    26
# 27    36
# 28    32
# 29    44
# 30    14
# 31    43
# 32    43
# 33    29
# 34    41
# 35    33
# 36    26
# 37    34
# 38    22
# 39    45
# 40    35
# 41    22
# 42    38
# 43    49
# 44    11
# 45    26
# 46    20
# 47    18
# 48    24
# 49    41
# dtype: int64

# %%
series_2 = pd.Series(np.random.randint(100, 1000, size=50))
series_2
# Out:
# 0     752
# 1     577
# 2     718
# 3     384
# 4     404
# 5     968
# 6     462
# 7     584
# 8     810
# 9     509
# 10    838
# 11    933
# 12    638
# 13    910
# 14    442
# 15    911
# 16    864
# 17    587
# 18    894
# 19    125
# 20    514
# 21    532
# 22    848
# 23    899
# 24    564
# 25    301
# 26    448
# 27    896
# 28    193
# 29    794
# 30    747
# 31    667
# 32    613
# 33    996
# 34    559
# 35    321
# 36    615
# 37    887
# 38    369
# 39    933
# 40    503
# 41    184
# 42    315
# 43    955
# 44    540
# 45    994
# 46    548
# 47    653
# 48    732
# 49    317
# dtype: int64

# %%
df = pd.DataFrame({'col1' : series_1, 'col2' : series_2})
df
# Out:
#     col1  col2
# 0     24   752
# 1     12   577
# 2     47   718
# 3     27   384
# 4     48   404
# 5     16   968
# 6     47   462
# 7     35   584
# 8     13   810
# 9     22   509
# 10    36   838
# 11    16   933
# 12    37   638
# 13    43   910
# 14    14   442
# 15    33   911
# 16    23   864
# 17    10   587
# 18    35   894
# 19    12   125
# 20    15   514
# 21    23   532
# 22    23   848
# 23    48   899
# 24    31   564
# 25    12   301
# 26    26   448
# 27    36   896
# 28    32   193
# 29    44   794
# 30    14   747
# 31    43   667
# 32    43   613
# 33    29   996
# 34    41   559
# 35    33   321
# 36    26   615
# 37    34   887
# 38    22   369
# 39    45   933
# 40    35   503
# 41    22   184
# 42    38   315
# 43    49   955
# 44    11   540
# 45    26   994
# 46    20   548
# 47    18   653
# 48    24   732
# 49    41   317

# %%
# 12. Perform the following operations using people data set:

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset.

# b) Delete the rows containing any missing values.

# d) Print the final output also.

df1 = pd.read_csv('https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk')
df1
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
df1 = df1.drop(columns=['Email', 'Phone', 'Date of birth'])

# %%
df1 = df1.dropna()
df1
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the
# following tasks using Matplotlib and NumPy:

# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.

# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.

# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.

# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.

# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.

# f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, color='red', marker='o', label='Random Points')
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Advanced Scatter Plot of Random Values')
plt.legend()
plt.show()

# %%
# 14. Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and
# Perform the following tasks using Matplotlib:

# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and
# right y-axis for 'Humidity').

# b) Label the x-axis as 'Date'.

# c) Set the title of the plot as 'Temperature and Humidity Over Time'.

import pandas as pd

dates = pd.date_range(start='2024-10-01', periods=100, freq='D')
temperature = np.random.uniform(20, 30, size=100)
humidity = np.random.uniform(40, 60, size=100)

df = pd.DataFrame({
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity})

df.set_index('Date', inplace=True)

df
# Out:
#             Temperature   Humidity
# Date
# 2024-10-01    21.720249  47.598415
# 2024-10-02    24.966066  51.167639
# 2024-10-03    21.414464  49.741238
# 2024-10-04    24.048043  58.477837
# 2024-10-05    21.153895  54.232246
# ...                 ...        ...
# 2025-01-04    22.516537  59.826763
# 2025-01-05    22.385172  41.704253
# 2025-01-06    29.642232  44.822343
# 2025-01-07    25.912620  54.799726
# 2025-01-08    28.033781  42.912152
#
# [100 rows x 2 columns]

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(df['Temperature'], color='red', label='Temperature')
plt.ylabel('Temperature')
plt.xlabel('Date')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(df['Humidity'], color='blue', label='Humidity')
plt.ylabel('Humidity')
plt.xlabel('Date')
plt.legend()

plt.title('Temperature and Humidity Over Time')
plt.show()

# %%
# 15,16. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:

# a) Plot a histogram of the data with 30 bins.

# b) Overlay a line plot representing the normal distribution's probability density function (PDF).

# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.

# d) Set the title of the plot as 'Histogram with PDF Overlay'.

data = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(data, bins=30, color='blue', alpha = 0.8, label='Histogram')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

mean = 0
std_dev = 1
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)
plt.plot(x, pdf, color='red', label='PDF')
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')
plt.title('Histogram with PDF Overlay')
plt.legend()
plt.show()

# %%
# 17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the
# origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

import seaborn as sns

x = np.random.rand(100) * 10
y = np.random.rand(100) * 10

data = pd.DataFrame({'X': x, 'Y': y})

def get_quadrant(row):
    if row['X'] >= 5 and row['Y'] >= 5:
        return 'Quadrant 1'
    elif row['X'] < 5 and row['Y'] >= 5:
        return 'Quadrant 2'
    elif row['X'] < 5 and row['Y'] < 5:
        return 'Quadrant 3'
    else:
        return 'Quadrant 4'

data['Quadrant'] = data.apply(get_quadrant, axis=1)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='X', y='Y', hue='Quadrant', palette='Set1', style='Quadrant', s=100)

plt.legend(title='Quadrants')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.title('Quadrant-wise Scatter Plot')

plt.show()

# %%
from re import X
# 18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
import numpy as np
from bokeh.plotting import figure, output_file, show

output_file('sine.html')

x = np.random.rand(100)
y = np.sin(x)

p = figure(title='Sine Wave Function')
p.xaxis.axis_label = 'X'
p.yaxis.axis_label = 'Sin(X)'
p.line(x, y)
show(p)
# Out:
#   <div id="e0e77b27-235e-43ca-81bc-635374fa673c" data-root-id="p1086" style="display: contents;"></div>

# %%
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values,
# label the axes, and set the title as 'Random Categorical Bar Chart'.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
import numpy as np
import pandas as pd

output_notebook()

categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 20, size=len(categories))

data = pd.DataFrame({'Category': categories, 'Value': values})

data['Color'] = ['#%02x%02x%02x' % (int(255 * (v / max(values))), 0, 0) for v in values]

source = ColumnDataSource(data=data)

p = figure(x_range=categories, title='Random Categorical Bar Chart',
           x_axis_label='Category', y_axis_label='Value', width=800, height=400)

p.grid.grid_line_color = 'gray'

bars = p.vbar(x='Category', top='Value', source=source,
              line_color='white',
              fill_color='Color',
              legend_label='Values')

hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

show(p)
# Out:
#   <div id="ccf8e4a8-e0af-45f3-8dea-da60ad992ae9" data-root-id="p1277" style="display: contents;"></div>

# %%
#  20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as
# 'Simple Line Plot'.

import plotly.graph_objects as go
import numpy as np

x = np.linspace(0, 10, 100)
y = np.random.rand(100)

fig = go.Figure()

fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set
# the title as 'Interactive Pie Chart'.

# %%
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(1, 100, size=len(labels))

fig = go.Figure(data=[go.Pie(labels=labels, values=values,
                               textinfo='percent+label')])

fig.update_layout(title='Interactive Pie Chart')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
