# %%
#Theory Questions
#1. What is the difference between a function and a method in Python?

#Function: A function is a block of reusable code that performs a specific task and is defined using the def keyword,
#and it can be called independently.

#Method: A method is a function that is associated with an object or class and is called on that object or class,
#defined within a class using the def keyword.

# %%
#2.  Explain the concept of function arguments and parameters in Python.

#Parameters: Parameters are the variables listed in the function definition that receive values when the function is called.

#Arguments: Arguments are the actual values or expressions passed to the function when it is called, which are assigned to the function’s parameters.

# %%
#3.  What are the different ways to define and call a function in Python?

#Defining a function: Use the def keyword followed by the function name, parentheses with optional parameters, and a colon, then indent the function body.
#Example:
def add(a, b):
  '''addition of two numbers'''
  return a+b

# %%
#Calling a function: Invoke the function by using its name followed by parentheses, including any necessary arguments within the parentheses.
#Example
add(3, 7)
# Out:
# 10

# %%
#4. What is the purpose of the `return` statement in a Python function?

#The `return` statement in a Python function is used to exit the function and send back a value to the caller
# allowing the function to produce a result.
# Example:
def square(a):
  '''square of a number'''
  return a ** 2

# %%
square(5)
# Out:
# 25

# %%
#5. What are iterators in Python and how do they differ from iterables?

# **Iterators**: Iterators are objects that implement the `__iter__()` and `__next__()` methods
# allowing iteration over a sequence of values one at a time.

# **Iterables**: Iterables are objects that implement the `__iter__()` method and can be used to obtain an iterator
# but they do not necessarily implement `__next__()` themselves.

# %%
#6. Explain the concept of generators in Python and how they are defined.

#Generators: Generators are a type of iterable in Python that allow you to create a sequence of values lazily
# using the yield statement to produce values one at a time and maintain state between iterations.

#Defining Generators: Generators are defined using a function with the yield keyword instead of return
# which allows the function to produce a series of values on demand.

#Example:
def fib(n):
  '''The Fibonacci sequence '''
  a, b = 0, 1
  for i in range(n):
    yield a
    a, b = b, a + b

# %%
fb = fib(1000)
fb
# Out:
# <generator object fib at 0x780c2e9e7c30>

# %%
next(fb)
# Out:
# 0

# %%
next(fb)
# Out:
# 1

# %%
next(fb)
# Out:
# 1

# %%
next(fb)
# Out:
# 2

# %%
next(fb)
# Out:
# 3

# %%
next(fb)
# Out:
# 5

# %%
#7. What are the advantages of using generators over regular functions?

#Here are some key advantages of using generators over regular functions:

# **Memory Efficiency**: Generators produce values one at a time and only when needed, which can
# be more memory-efficient than generating an entire sequence at once.

# **Lazy Evaluation**: Generators compute values on-the-fly, allowing for processing of
# large data sets or infinite sequences without the need to store the entire sequence in memory.

# **Improved Performance**: By generating values as needed, generators can reduce the overhead
# associated with creating and managing large collections of data.

# **Simplified Code**: Generators can simplify code that requires iteration over large sequences
# as they eliminate the need for explicit state management and can be written in a more concise form.

# %%
#8. What is a lambda function in Python and when is it typically used?

# A lambda function in Python is an anonymous, small, one-line function defined using the lambda keyword
# typically used for simple operations or as a quick, throwaway function.

#Key Points:
#Syntax: lambda(arguments: expression)
#Usage: Lambda functions are often used in situations where a short, unnamed function is needed
# or when passing a simple function as an argument.

# %%
#9. Explain the purpose and usage of the `map()` function in Python.

#The map() function in Python applies a given function to each item in an iterable (like a list) and returns a map
#object (which is an iterator) containing the results.

#Purpose:
#To transform or apply a function to each element of an iterable efficiently.
#Usage:
#Syntax: map(function, iterable)
#Example:
l1 = [2, 5, 7, 9, 4]
sq_num = list(map(lambda x: x**2, l1))
sq_num
# Out:
# [4, 25, 49, 81, 16]

# %%
#In this example:

#square is applied to each element of numbers.
#map() returns an iterator that yields the squared values.
#list() is used to convert the map object to a list for display purposes.

# %%
#10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

#Here's a brief comparison of the map(), reduce(), and filter() functions in Python:

#map():

#Purpose: Applies a function to each item in an iterable and returns a map object with the results.
#Usage: map(function, iterable)
#Example: map(lambda x: x * 2, [1, 2, 3]) produces [2, 4, 6].
list(map(lambda x: x * 2, [1, 2, 3]))
# Out:
# [2, 4, 6]

# %%
#reduce() (from the functools module):

#Purpose: Applies a function cumulatively to the items of an iterable, reducing it to a single value.
#Usage: reduce(function, iterable)
#Example: reduce(lambda x, y: x + y, [1, 2, 3, 4]) produces 10.
from functools import reduce
reduce(lambda x, y: x + y, [1, 2, 3, 4])
# Out:
# 10

# %%
#filter():

#Purpose: Applies a function to each item in an iterable and returns an iterator with items for which the function returns True.
#Usage: filter(function, iterable)
#Example: filter(lambda x: x % 2 == 0, [1, 2, 3, 4]) produces [2, 4].
list(filter(lambda x: x % 2 == 0, [1, 2, 3, 4]))
# Out:
# [2, 4]

# %%
#11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
#list:[47,11,42,13];
l1 = [47,11,42,13]
from functools import reduce
sum = reduce(lambda a,b: a + b, l1)
print(sum)
# Out:
# 113

# %% [markdown]
# ![WhatsApp Image 2024-09-22 at 12.20.01 AM.jpeg](data:image/jpeg;base64,...)

# %%
#Practical Questions:
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def sum_of_even(l):
  """returns sum of all even numbers in a list"""
  return sum(i for i in l if i%2 == 0)

# %%
l = [1, 3, 4, 2, 6, 7, 8, 4, 9]
sum_of_even(l)
# Out:
# 24

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.

def rev_string(s):
  """returns a reverse string"""
  return s[ : : -1]

# %%
s = "Hello"
rev_string(s)
# Out:
# 'olleH'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def sq_num(nums):
  """returns list containing the squares of each number"""
  l = []
  for i in nums:
    l.append(i**2)
  return l

# %%
nums = [2, 5, 6, 3, 9]
sq_num(nums)
# Out:
# [4, 25, 36, 9, 81]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.

def is_prime(n):
    if n <= 1:
        return False
    if n == 2:
        return True  # 2 is the only even prime number
    if n % 2 == 0:
        return False  # All other even numbers are not prime
    for i in range(3, int(n**0.5) + 1, 2):
        if n % i == 0:
            return False
    return True

# %%
is_prime(4)
# Out:
# False

# %%
is_prime(29)
# Out:
# True

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

def fib(n):
  '''The Fibonacci sequence '''
  a, b = 0, 1
  for i in range(n):
    yield a
    a, b = b, a + b

# %%
f = fib(150)
f
# Out:
# <generator object fib at 0x7dd770203530>

# %%
next(f)
# Out:
# 0

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 2

# %%
next(f)
# Out:
# 3

# %%
next(f)
# Out:
# 5

# %%
next(f)
# Out:
# 8

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def power_of_2(exponent):
  for i in range(exponent + 1): #+1 to include the exponent
    yield 2 ** i

# %%
p = power_of_2(5)
p
# Out:
# <generator object power_of_2 at 0x7dd770295930>

# %%
next(p)
# Out:
# 1

# %%
next(p)
# Out:
# 2

# %%
next(p)
# Out:
# 4

# %%
next(p)
# Out:
# 8

# %%
next(p)
# Out:
# 16

# %%
next(p)
# Out:
# 32

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
from google.colab import drive;
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_file_line_by_line(file_path):
    """Generator function to read a file line by line."""
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()


file_path = '/content/drive/MyDrive/pw_skills/python.rtf'

next(read_file_line_by_line(file_path))
# Out:
# '{\\rtf1\\ansi\\ansicpg1252\\cocoartf2639'

# %%
|#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

data = [(1, 'apple'), (2, 'cherry'), (3, 'banana')]
sorted_data = sorted(data, key=lambda x: x[1])

# %%
sorted_data
# Out:
# [(1, 'apple'), (3, 'banana'), (2, 'cherry')]

# %%
data = [(1, 'a', 8), (2, 'r', 2), (3, 'c', 5)]
sorted_data = sorted(data, key=lambda x: x[1])

# %%
sorted_data
# Out:
# [(1, 'a', 8), (3, 'c', 5), (2, 'r', 2)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

celsius_temp = [25, 56, 74, 12]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temp))

# %%
fahrenheit_temps
# Out:
# [77.0, 132.8, 165.2, 53.6]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
string = "Hello Python"
l = list(filter(lambda a: a not in ['a', 'A', 'e', 'E', 'i', 'I', 'o', 'O', 'u', "U"], string))
result = "".join(l)
print(result)
# Out:
# Hll Pythn

# %%
#11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:


#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
#product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#order is smaller than 100,00 €.

#Write a Python program using lambda and map.

order_no = [1, 2, 3, 4, 5]
price_per_item = [30, 20, 50, 70, 10]
quantity = [3, 5, 1, 2, 4]
total_price = list(map(lambda price, qty: price * qty if (price * qty) >= 100 else (price * qty) + 10, price_per_item, quantity))
result = []
for i in range(0, len(order_no)):
  result.append((order_no[i], total_price[i]))
print(result)
# Out:
# [(1, 100), (2, 100), (3, 60), (4, 140), (5, 50)]
